# %%
class Vehicul:
    def deplasare(self):
        print("Vehiculul se deplaseaza")

class Masina(Vehicul):
    def claxoneaza(self):
        print("claxoneaza")



class Dacia(Masina):
    def afisare(self):
        print("Eu sunt dacia")

class Logan(Dacia):
    def afisezLogan(self):
        print("Sunt logan")

class Sandero:
    def afisezSandero(self):
        print("Sunt sandero")

class Corcitura(Sandero, Logan):
    def combinatie(self):
        print("Eu sunt combinatie")


""""
d = Dacia(100)
l = Logan(20)
d.afisare()
l.afisezLogan()
"""
s = Sandero()
c = Corcitura()
c.combinatie()
s.afisezSandero()
# Out:
# Eu sunt combinatie
# Sunt sandero
