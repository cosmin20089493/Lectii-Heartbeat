# %% [markdown]
# Lista
#
# current= curr
# node = nod
#
#
# Lista dubla inlantuita
#
# -pronim de la un nod
#
# ![image.png](attachment:0172e736-7cad-4cff-8cec-7bdbc6c24242.png)
#
# comunicarea este tot timpul unidirectionala. (exemplu...cod morse)
#
# ![image.png](attachment:6442e89b-b27c-4d8c-b8b1-36266ec3a5a2.png)
