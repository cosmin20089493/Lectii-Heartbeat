# %% [markdown]
# Un altgoritm de sortare este de fapt o structura de rearanjare a elementelor: ->crescator
#
#                                                                           :->descrescator
#
# Tipuri de algoritmi: complexitate si viteza de procesare
#
# Clasificarea alg de sortare:  -simplii vs eficienti
#                                -implace vs extramemorie
#                                -stabili vs hectabili
#
#
# 3.Sortari simple:
#
#     3.1 sortarea cea mai simpla: - Bubble sort- com para elementele ,revine si le schimba daca sunt in ordine gresita.
#
# Complexitate: timp O(npatrat)
#                spatiu o(1)
#                stabil=???
#
#     3.2 Selectiion Sort -cauta minim si il pune pe pozitie corecta
#
# Timp= o(npatrat)
#
# spatiu=o(1)
#
# stabil= ???
#
#     3.3 Inserare sort-   o(n)
#
#                          o(n2)
#
#                            stabil???
#
#     3.4 Merge Sort -> Divide impera  T=o(n)
#
#
#
#     3.5 Quick Sort   :alege un pivot si impoarte sirul la 2s
#
# Cele cinci sortari
#
# BSIMQ   (bubule, Selection, Insarte, Merge, Quick)
#
#
#
# Complexitate:  O(n log n)
#
#
# Operatii de baza:
#
# 1. Comparatia   >=<
#
#
# 2.Atribuim  inseram
#
# 3.Incrementare
#
#
#
#
#
#
# ![image.png](attachment:b50f9ce1-2fdb-4e65-b75d-7b938d1b526f.png)
#
#
#
# ![image.png](attachment:ca09f4c7-8122-4392-9f91-df1c1c0593ab.png)
